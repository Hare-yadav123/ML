# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from  sklearn.preprocessing  import OneHotEncoder,OrdinalEncoder,LabelEncoder,StandardScaler,MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.compose import ColumnTransformer

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
encode=pd.get_dummies(df['Sex'],drop_first=True)
print(encode)
# Out:
#       male
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# ..     ...
# 886   True
# 887  False
# 888  False
# 889   True
# 890   True
#
# [891 rows x 1 columns]

# %%
df.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
x = df[['Pclass','Age','SibSp','Parch','Fare','Sex','Embarked']]
y = df['Survived']

# %%
# from sklearn.feature_selection import SelectKBest,chi2
# bestfeature = SelectKBest(score_func=chi2, k=7)
# fit = bestfeature.fit(x,y)
# fit

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
categorical_features = ['Sex','Embarked']
numerical_features = ['Pclass','Age','SibSp','Parch','Fare']

# %%
from sklearn.impute import SimpleImputer
missing_values = Pipeline(steps=[
    ('imputer',SimpleImputer(strategy = 'median')),
    ('scaler',StandardScaler())
])

# %%
cat_miss_values = Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='most_frequent')),
    ('ohe',OneHotEncoder(sparse_output=False,handle_unknown='ignore'))
])

# %%
column_transformer = ColumnTransformer(transformers=[
    ('num',missing_values,numerical_features),
    ('cat',cat_miss_values,categorical_features)
])

# %%
dtc = DecisionTreeClassifier(random_state=42)
rfc = RandomForestClassifier(random_state=42)

# %%
pipeline = Pipeline(steps=[
    ('process',column_transformer),
    ('dtc',dtc)
])

# %%
pipeline1 = Pipeline(steps=[
    ('process',column_transformer),
    ('rfc',rfc)
])

# %%
pipeline.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('process',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Pclass', 'Age', 'SibSp',
#                                                    'Parch', 'Fare']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
# ...

# %%
pipeline1.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('process',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Pclass', 'Age', 'SibSp',
#                                                    'Parch', 'Fare']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
# ...

# %%
y_pred =pipeline.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7761194029850746

# %%
y_pred1 =pipeline1.predict(x_test)
print('rfc accuracy:',accuracy_score(y_test,y_pred1))
# Out:
# rfc accuracy: 0.7798507462686567

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[127,  30],
#        [ 30,  81]])

# %%
confusion_matrix(y_test,y_pred1)
# Out:
# array([[132,  25],
#        [ 34,  77]])

# %%
import pickle

pickle.dump(pipeline1,open('modelusersurvive.pk1','wb'))

# %%
# df.drop(['Name'],axis = 1)

# %%
# x1 = pd.get_dummies(x,drop_first=True)

# %%
# from sklearn.feature_selection import  SelectKBest,chi2
# bestfeature = SelectKBest(score_func=chi2,k=7)
# # bestfeature.fit(x1,y)

# %%
# x1['Age'] = x1['Age'].fillna(x1['Age'].median())

# %%
# x1.isnull().sum()

# %%
# from sklearn.feature_selection import  SelectKBest,chi2
# bestfeature = SelectKBest(score_func=chi2,k=7)
# fit=bestfeature.fit(x1,y)

# %%
# fit.scores_

# %%
# fit.feature_names_in_

# %%
# fit.fit_transform

# %%
import streamlit as st
import pickle
model = pickle.load(open('modelusersurvive.pk1','rb'))

# %%
st.title('model for survive prediction')

Pclass = st.number_input('Pclass')
Age = st.number_input('Age')
SibSp = st.number_input('sibSp')
Parch = st.number_input('Parch')
Fare = st.number_input('Fare')
Sex = st.number_input('Sex')
Embarked = st.number_input('Embarked')
# Out:
# 2026-03-29 18:33:22.969 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 18:33:22.971 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 18:33:22.972 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 18:33:22.975 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 18:33:22.978 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 18:33:22.979 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 18:33:22.981 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
if st.button('predict'):
    input_data = pd.DataFrame([{
        'Pclass':Pclass,
        'Age':Age,
        'SibSp':SibSp,
        'Parch':Parch,
        'Fare':Fare,
        'Sex':Sex,
        'Embarked':Embarked
    }])
    predections = model.predict(input_data)
    st.success(f'prediction is : {predections}')
# Out:
# 2026-03-29 18:33:17.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 18:33:17.628 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 18:33:17.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 18:33:17.631 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 18:33:17.632 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-29 18:33:17.634 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
